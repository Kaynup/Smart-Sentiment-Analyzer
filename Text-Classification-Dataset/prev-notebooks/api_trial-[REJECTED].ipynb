# %% [markdown]
# # Loading precleaned datasets

# %%
import polars as pl
import numpy as np

# %%
pre_1 = pl.read_csv("Precleaned-Data/precleaned_chunk_1.csv", separator='~', quote_char='"')

# %%
pre_1.head()
# Out:
# shape: (5, 3)
# ┌─────────────────────────────────┬────────────┬─────────────────────────────────┐
# │ body                            ┆ subreddit  ┆ body_cleaned                    │
# │ ---                             ┆ ---        ┆ ---                             │
# │ str                             ┆ str        ┆ str                             │
# ╞═════════════════════════════════╪════════════╪═════════════════════════════════╡
# │ Brick                           ┆ r-3amjokes ┆ Brick                           │
# │ Ban wave #2 is complete, pleas… ┆ r-3amjokes ┆ Ban wave #2 is complete, pleas… │
# │ I'm not an insomniac, but I am… ┆ r-3amjokes ┆ I'm not an insomniac, but I am… │
# │ Hear you loud and clear, thank… ┆ r-3amjokes ┆ Hear you loud and clear, thank… │
# │ I had no idea this sub had mod… ┆ r-3amjokes ┆ I had no idea this sub had mod… │
# └─────────────────────────────────┴────────────┴─────────────────────────────────┘

# %%
def polars_info(df: pl.DataFrame):
    print("Shape:", df.shape)
    print("\nSchema:")
    for name, dtype in df.schema.items():
        print(f" - {name}: {dtype}")
    print("\nNull Counts:")
    print(df.null_count())

polars_info(pre_1)
# Out:
# Shape: (400000, 3)
#
# Schema:
#  - body: String
#  - subreddit: String
#  - body_cleaned: String
#
# Null Counts:
# shape: (1, 3)
# ┌──────┬───────────┬──────────────┐
# │ body ┆ subreddit ┆ body_cleaned │
# │ ---  ┆ ---       ┆ ---          │
# │ u32  ┆ u32       ┆ u32          │
# ╞══════╪═══════════╪══════════════╡
# │ 0    ┆ 0         ┆ 0            │
# └──────┴───────────┴──────────────┘

# %% [markdown]
# # Funnelling special characters

# %%
import csv
import string
import unicodedata
import emoji

# %%
# Path to your CSV file
csv_file_path = 'Precleaned-Data/precleaned_chunk_1.csv'

# Sets to collect characters
punctuations_found = set()
emojis_found = set()
special_chars_found = set()

# Function to extract emojis (real emojis, even if multi-char)
def extract_emojis(text):
    return [match["emoji"] for match in emoji.emoji_list(text)]

# Open and read the CSV file with correct delimiter and quote character
with open(csv_file_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile, delimiter='~', quotechar='"')
    for row in reader:
        for cell in row:
            # Emojis (multi-char supported)
            emojis = extract_emojis(cell)
            emojis_found.update(emojis)

            for char in cell:
                if char in string.punctuation:
                    punctuations_found.add(char)
                elif not char.isalnum() and not char.isspace() and char not in emojis:
                    special_chars_found.add(char)

# Sort and print results
print("Punctuation marks found in the CSV:")
print(" ".join(sorted(punctuations_found)))

print("\nEmojis found in the CSV:")
print(" ".join(sorted(emojis_found)))

print("\nOther special characters found in the CSV:")
print(" ".join(sorted(special_chars_found)))
# Out:
# Punctuation marks found in the CSV:
# ! " # $ % & ' ( ) * + , - . / : ; < = > ? @ [ \ ] ^ _ ` { | } ~
#
# Emojis found in the CSV:
# ¡ ¢ £ ¤ ¥ § © « ¬ ¯ ° ± ´ · » ¿ × ÷ ˵ ˶ ̀ ́ ̂ ̃ ̄ ̅ ̆ ̇ ̈ ̉ ̊ ̋ ̌ ̍ ̎ ̏ ̐ ̑ ̒ ̓ ̔ ̕ ̖ ̗ ̘ ̙ ̚ ̛ ̜ ̝ ̞ ̟ ̠ ̡ ̢ ̣ ̤ ̥ ̦ ̧ ̨ ̩ ̪ ̫ ̬ ̭ ̮ ̯ ̰ ̱ ̲ ̳ ̴ ̵ ̶ ̷ ̸ ̹ ̺ ̻ ̼ ̽ ̾ ̿ ̀ ́ ͂ ̓ ̈́ ͅ ͆ ͇ ͈ ͉ ͊ ͋ ͌ ͍ ͎ ͏ ͐ ͑ ͒ ͓ ͔ ͕ ͖ ͗ ͘ ͙ ͚ ͛ ͜ ͝ ͞ ͟ ͠ ͡ ͢ ͣ ͤ ͥ ͦ ͧ ͨ ͩ ͪ ͬ ͭ ͮ ͯ ; ҉ ִ ، ۝ ܰ ा ि ी े ී ี ื ุ ่ ้ ፣ ​ ‍ ‎ ‐ ‑ – — ― ‘ ’ ‚ “ ” „ • … ‬ ‭ ′ ‼ ‽ ‿ ⁉ ⁠ ₩ € ₹ ₽ ⃣ № ™ ← ↑ → ↔ ↕ ↖ ↗ ↘ ↙ ∆ ∈ − ∞ ∠ ∩ ≈ ≠ ≤ ≥ ⌐ ⏄ ⏱ ⏲ ⓘ ━ ┌ ┐ ┛ ┴ ┻ ╭ ╮ ╯ ▀ ■ □ △ ◀ ◉ ◍ ● ◕ ◠ ◡ ☀ ☄ ★ ☆ ☎ ☘ ☝ ☞ ☠ ☪ ☭ ☮ ☹ ☺ ☻ ♀ ♂ ♡ ♥ ♪ ♫ ♻ ♾ ⚔ ⚕ ⚖ ⚜ ⚠ ⚧ ⚰ ⚱ ⛏ ⛑ ⛓ ⛱ ⛸ ⛹ ✂ ✈ ✊ ✋ ✌ ✍ ✏ ✓ ✔ ✖ ✝ ✡ ✿ ❄ ❛ ❝ ❞ ❣ ❤ ➡ ⠀ ⠁ ⠂ ⠃ ⠄ ⠅ ⠆ ⠇ ⠈ ⠉ ⠊ ⠋ ⠌ ⠍ ⠏ ⠐ ⠑ ⠒ ⠓ ⠔ ⠖ ⠗ ⠘ ⠙ ⠚ ⠛ ⠜ ⠝ ⠞ ⠟ ⠠ ⠡ ⠢ ⠣ ⠤ ⠥ ⠦ ⠧ ⠨ ⠭ ⠰ ⠲ ⠳ ⠴ ⠶ ⠷ ⠸ ⠹ ⠺ ⠻ ⠼ ⠾ ⠿ ⡀ ⡁ ⡂ ⡃ ⡄ ⡅ ⡆ ⡇ ⡈ ⡉ ⡋ ⡌ ⡍ ⡎ ⡏ ⡑ ⡒ ⡔ ⡕ ⡗ ⡘ ⡙ ⡚ ⡜ ⡞ ⡟ ⡠ ⡤ ⡥ ⡦ ⡧ ⡩ ⡪ ⡫ ⡭ ⡰ ⡱ ⡴ ⡶ ⡷ ⡸ ⡻ ⡼ ⡾ ⡿ ⢀ ⢁ ⢂ ⢃ ⢄ ⢇ ⢈ ⢉ ⢊ ⢋ ⢎ ⢏ ⢐ ⢑ ⢒ ⢔ ⢘ ⢙ ⢛ ⢝ ⢟ ⢠ ⢣ ⢤ ⢦ ⢧ ⢨ ⢫ ⢭ ⢮ ⢯ ⢰ ⢱ ⢳ ⢶ ⢷ ⢸ ⢹ ⢻ ⢼ ⢽ ⢾ ⢿ ⣀ ⣁ ⣂ ⣃ ⣄ ⣅ ⣆ ⣇ ⣈ ⣉ ⣋ ⣌ ⣎ ⣐ ⣒ ⣔ ⣕ ⣖ ⣗ ⣙ ⣛ ⣜ ⣝ ⣟ ⣠ ⣡ ⣢ ⣣ ⣤ ⣥ ⣦ ⣧ ⣨ ⣩ ⣪ ⣫ ⣬ ⣭ ⣮ ⣯ ⣰ ⣱ ⣲ ⣴ ⣵ ⣶ ⣷ ⣸ ⣹ ⣺ ⣻ ⣼ ⣽ ⣾ ⣿ ⤴ ⤵ ⬅ ⬆ ⬇ ⬛ ⸻ 、 。 「 」 ︎ ️ ︵ ﹏ ﻿ ！ （ ） ， － ／ ？ ＼ ＾ ＿ ｀ ～ ￢ ￼ 🅰 🅱 🅳 🅴 🅶 🅽 🅾 🆇 🇦 🇧 🇨 🇩 🇪 🇫 🇬 🇭 🇮 🇯 🇰 🇱 🇲 🇳 🇴 🇵 🇶 🇷 🇸 🇹 🇺 🇻 🇼 🇽 🇾 🇿 🌈 🌥 🌩 🌪 🌫 🌬 🌶 🌾 🍳 🍽 🎓 🎖 🏃 🏄 🏌 🏍 🏖 🏞 🏳 🏴 🏻 🏼 🏽 🏾 🏿 🐈 🐦 🐿 👁 👃 👆 👈 👉 👊 👋 👌 👍 👎 👏 👦 👨 👩 👮 👱 👴 👵 👸 💁 💃 💅 💆 💇 💨 💪 💫 💻 📽 🔥 🔧 🕊 🕯 🕰 🕳 🕷 🕺 🖍 🖐 🖕 🖖 🗑 🗒 🗝 🗡 🗣 🗨 🗺 😮 😵 😶 🙂 🙅 🙆 🙇 🙋 🙌 🙍 🙏 🚀 🚶 🛋 🛏 🛢 🛤 🛥 🛰 🠉 🤌 🤏 🤘 🤙 🤚 🤛 🤜 🤝 🤞 🤟 🤦 🤳 🤴 🤷 🤸 🤾 🥷 🦯 🦱 🦲 🦳 🦵 🦸 🦹 🦼 🦽 🧍 🧑 🧔 🧗 🧙 🧚 🧛 🧟 🩹 🫃 🫰 🫱 🫲 🫳 🫴 🫵 🫶 󠁢 󠁣 󠁥 󠁧 󠁬 󠁮 󠁳 󠁴 󠁷 󠁿

# %% [markdown]
# # API meta-tagging

# %%
import os
import time
import polars as pl
from google import genai

client = genai.Client(api_key="AIzaSyD-Fc6V_NuYwLIqiX4EZpF-J-rOHHY52oQ")

# %%
try:
    df = pl.read_csv("Precleaned-Data/precleaned_chunk_1.csv", separator='~', quote_char='"')
    texts = df["body_cleaned"].to_list()
    print(f"Loaded {len(texts)} reviews from file.")
except Exception as e:
    print(f"Failed to read input CSV: {e}")
    texts = []

# Configuration
batch_size = 20
total = len(texts)
models_to_try = ["gemini-2.5-flash", "gemini-2.5-pro"]
output_file = "labelled_output_chunk_1.csv"
header_written = os.path.exists(output_file)

if not texts:
    print("No texts found to process. Exiting.")
else:
    total_batches = (total + batch_size - 1) // batch_size
    print(f"📦 Starting processing: {total_batches} batches of up to {batch_size} reviews each.")

    for batch_num, i in enumerate(range(0, total, batch_size), start=1):
        print(f"\nBatch {batch_num}/{total_batches} — Processing reviews {i + 1} to {min(i + batch_size, total)}")
        batch_start_time = time.time()

        batch_reviews = texts[i:i + batch_size]
        reviews_block = "\n".join(batch_reviews)

        prompt = f'''
Classify each review using the schema and rules below.

**Output Format**
- CSV format
- Separator: ⁓
- Quote character: "
- Column order: "text","label","tone","context","contains_slang","complexity","causal","contains_gibberish"

**Column Definitions**
- **text**: Original review (unchanged — preserve punctuation, emojis, and casing).
- **label**: One of "positive", "neutral", or "negative".
- **tone**: One of: "sincere", "sarcastic", or "neutral".
- **context**: Always "comment" or "review".
- **contains_slang**: "true" if slang, vulgarity, emojis with sexual tone, wordplay involving body parts, or innuendo is used; otherwise "false".
- **complexity**: "low", "medium", or "high".
- **causal**: "true" if reasoning, explanation, cause-effect, blame, or justification exists; else "false".
- **contains_gibberish**: "true" if the text contains random characters, non-words, nonsensical phrases, or emoji-only content that lacks structure or meaning; otherwise "false".

**Annotation Rules**
1. Never alter the original review text.
2. Gibberish or emoji-only → `contains_gibberish=true` and `tone=sarcastic`
3. Puns, dirty jokes → `contains_slang=true`, `tone=sarcastic`
4. Emoji-only texts → infer sentiment unless meaningless
5. Sarcasm → `tone=sarcastic`, complexity ≥ "medium"
6. Reasoning or cause → `causal=true`

Start your output with this header:
"text","label","tone","context","contains_slang","complexity","causal","contains_gibberish"

Reviews:
{reviews_block}
'''

        raw_output = ""
        success = False
        model_start_time = time.time()

        for model_name in models_to_try:
            try:
                print(f"🧪 Trying model: {model_name}")
                response = client.models.generate_content(
                    model=model_name,
                    contents=prompt
                )

                if hasattr(response, 'text') and response.text:
                    raw_output = response.text.strip()
                elif hasattr(response, 'candidates'):
                    raw_output = response.candidates[0].content.parts[0].text.strip()
                else:
                    print(f"⚠️ {model_name} returned no usable content.")
                    continue

                print(f"Model {model_name} succeeded.")
                success = True
                break

            except Exception as e:
                print(f"Error using model {model_name}: {e}")
                continue

        model_duration = round(time.time() - model_start_time, 2)

        if not success:
            print(f"Skipping batch {batch_num} due to total model failure.")
            continue

        print(f"Output generated in {model_duration}s")
        print("Output Preview:\n", raw_output[:300])
        print("-" * 80)

        # Writing output to file
        try:
            with open(output_file, "a", encoding="utf-8") as f:
                lines = raw_output.strip().split("\n")

                if not header_written and lines[0].startswith('"text"'):
                    f.write(lines[0] + "\n")
                    f.write("\n".join(lines[1:]) + "\n")
                    header_written = True
                elif lines[0].startswith('"text"'):
                    f.write("\n".join(lines[1:]) + "\n")
                else:
                    f.write(raw_output + "\n")

            print(f"Batch {batch_num} written to {output_file}")
        except Exception as e:
            print(f"Failed to write to output file: {e}")

        batch_total_time = round(time.time() - batch_start_time, 2)
        print(f"Batch {batch_num} completed in {batch_total_time}s")

        if batch_num % 5 == 0 and (i + batch_size) < total:
            print("Sleeping for 5 seconds to prevent overload...")
            time.sleep(5)
# Out:
# 📄 Loaded 400000 reviews from file.
# 📦 Starting processing: 20000 batches of up to 20 reviews each.
#
# 🚀 Batch 1/20000 — Processing reviews 1 to 20
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 23.47s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Brick"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Ban wave #2 is complete, please keep reporting the shitheels so i can be entertained by sob stories in modmail. > Bans due to rule #4 tend
# --------------------------------------------------------------------------------
# 💾 Batch 1 written to labelled_output.csv
# ✅ Batch 1 completed in 23.47s
#
# 🚀 Batch 2/20000 — Processing reviews 21 to 40
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 30.22s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Just getting your wanks in a row"⁓"negative"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "Organized by the spewy-decimal system?"⁓"negative"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "Y
# --------------------------------------------------------------------------------
# 💾 Batch 2 written to labelled_output.csv
# ✅ Batch 2 completed in 30.22s
#
# 🚀 Batch 3/20000 — Processing reviews 41 to 60
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 20.54s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Spanky"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "Overcomer"⁓"positive"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "I confess"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false
# --------------------------------------------------------------------------------
# 💾 Batch 3 written to labelled_output.csv
# ✅ Batch 3 completed in 20.54s
#
# 🚀 Batch 4/20000 — Processing reviews 61 to 80
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 26.22s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "blind"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Spermadian bruh"⁓"negative"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"true"
# "that made me gigglee"⁓"positive"⁓"sincere"⁓"comment"⁓"fal
# --------------------------------------------------------------------------------
# 💾 Batch 4 written to labelled_output.csv
# ✅ Batch 4 completed in 26.22s
#
# 🚀 Batch 5/20000 — Processing reviews 81 to 100
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 19.74s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Well if you go lower, it’s a snappah."⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "Gladys?"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "A blowjobster"⁓"neutral"⁓"sarcast
# --------------------------------------------------------------------------------
# 💾 Batch 5 written to labelled_output.csv
# ✅ Batch 5 completed in 19.74s
# 😴 Sleeping for 5 seconds to prevent overload...
#
# 🚀 Batch 6/20000 — Processing reviews 101 to 120
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 34.58s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "giggleeesss"⁓"positive"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Have you heard of Yoda’s Kindle app: “Read I must. Swipe I shall.”"⁓"positive"⁓"sincere"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
#
# --------------------------------------------------------------------------------
# 💾 Batch 6 written to labelled_output.csv
# ✅ Batch 6 completed in 34.58s
#
# 🚀 Batch 7/20000 — Processing reviews 121 to 140
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 18.65s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Wtf"⁓"negative"⁓"neutral"⁓"comment"⁓"true"⁓"low"⁓"false"⁓"false"
# "Bro just turned tree trauma into a metaphysical mic drop."⁓"positive"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "Hello I need com
# --------------------------------------------------------------------------------
# 💾 Batch 7 written to labelled_output.csv
# ✅ Batch 7 completed in 18.65s
#
# 🚀 Batch 8/20000 — Processing reviews 141 to 160
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 21.42s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Beginners should train the weak ends first."⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"medium"⁓"true"⁓"false"
# "The splits? Well, make it before hump day."⁓"positive"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false
# --------------------------------------------------------------------------------
# 💾 Batch 8 written to labelled_output.csv
# ✅ Batch 8 completed in 21.42s
#
# 🚀 Batch 9/20000 — Processing reviews 161 to 180
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 28.32s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "They have a lot of chips tho"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "I’m watching pet cemetery and eating cheezits also. The white cheddar kind"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"m
# --------------------------------------------------------------------------------
# 💾 Batch 9 written to labelled_output.csv
# ✅ Batch 9 completed in 28.32s
#
# 🚀 Batch 10/20000 — Processing reviews 181 to 200
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 29.78s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "I thought that might be the the punchline long before I saw the punchline"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "Yeah, I quit drinking too... until happy hour hits."⁓"neutral"⁓"sinc
# --------------------------------------------------------------------------------
# 💾 Batch 10 written to labelled_output.csv
# ✅ Batch 10 completed in 29.78s
# 😴 Sleeping for 5 seconds to prevent overload...
#
# 🚀 Batch 11/20000 — Processing reviews 201 to 220
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 23.93s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Idk... butt I'm starting to come all over my sandwich 🥪"⁓"negative"⁓"sarcastic"⁓"review"⁓"true"⁓"medium"⁓"false"⁓"false"
# "Peanut"⁓"neutral"⁓"neutral"⁓"review"⁓"false"⁓"low"⁓"false"⁓"false"
# "Should be "what's
# --------------------------------------------------------------------------------
# 💾 Batch 11 written to labelled_output.csv
# ✅ Batch 11 completed in 23.93s
#
# 🚀 Batch 12/20000 — Processing reviews 221 to 240
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 22.13s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "True, true."⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Someone watched Love Island last night"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "Let's roll"⁓"neutral"⁓"sincer
# --------------------------------------------------------------------------------
# 💾 Batch 12 written to labelled_output.csv
# ✅ Batch 12 completed in 22.13s
#
# 🚀 Batch 13/20000 — Processing reviews 241 to 260
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 25.35s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Fuckus bummus"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "Inya Ranus!"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "Giraffe walked into a bar and says” the high ball
# --------------------------------------------------------------------------------
# 💾 Batch 13 written to labelled_output.csv
# ✅ Batch 13 completed in 25.35s
#
# 🚀 Batch 14/20000 — Processing reviews 261 to 280
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 21.44s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "What do you call I guy with no arms and legs flying over a fence? Homer"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "What do you call a guy with no arms and no legs under a car? Jack"⁓"n
# --------------------------------------------------------------------------------
# 💾 Batch 14 written to labelled_output.csv
# ✅ Batch 14 completed in 21.44s
#
# 🚀 Batch 15/20000 — Processing reviews 281 to 300
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 28.72s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "What do you call a girl with no arms or legs being eaten by cannibals? Sharon"⁓"negative"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "What do you call a boy with no arms or legs on the playground?
# --------------------------------------------------------------------------------
# 💾 Batch 15 written to labelled_output.csv
# ✅ Batch 15 completed in 28.72s
# 😴 Sleeping for 5 seconds to prevent overload...
#
# 🚀 Batch 16/20000 — Processing reviews 301 to 320
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 21.63s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "My arse and your face. There's a match 🤣"⁓"negative"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "I got a patch of palm fronds you can use."⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"fal
# --------------------------------------------------------------------------------
# 💾 Batch 16 written to labelled_output.csv
# ✅ Batch 16 completed in 21.63s
#
# 🚀 Batch 17/20000 — Processing reviews 321 to 340
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 25.19s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Joke’s on him. Sister Theresa’s real name is Bob, and he’s on his way to a costume party."⁓"neutral"⁓"sarcastic"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "Must be nice to get that weight off of your head a
# --------------------------------------------------------------------------------
# 💾 Batch 17 written to labelled_output.csv
# ✅ Batch 17 completed in 25.19s
#
# 🚀 Batch 18/20000 — Processing reviews 341 to 360
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 21.78s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "It brayed to God."⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "It kicked the bucket"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Donkeeled over."⁓"neutral"⁓"sarcastic"⁓"comm
# --------------------------------------------------------------------------------
# 💾 Batch 18 written to labelled_output.csv
# ✅ Batch 18 completed in 21.78s
#
# 🚀 Batch 19/20000 — Processing reviews 361 to 380
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 31.34s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "As a veteran USMM, I definitely agree"⁓"positive"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "But they do have the backbone."⁓"positive"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "No Bones abo
# --------------------------------------------------------------------------------
# 💾 Batch 19 written to labelled_output.csv
# ✅ Batch 19 completed in 31.34s
#
# 🚀 Batch 20/20000 — Processing reviews 381 to 400
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 25.66s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "mods were on that lickety-split"⁓"positive"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Shit joke."⁓"negative"⁓"sincere"⁓"comment"⁓"true"⁓"low"⁓"false"⁓"false"
# "Oh no, you woke me up… I shaved my back
# --------------------------------------------------------------------------------
# 💾 Batch 20 written to labelled_output.csv
# ✅ Batch 20 completed in 25.67s
# 😴 Sleeping for 5 seconds to prevent overload...
#
# 🚀 Batch 21/20000 — Processing reviews 401 to 420
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 18.44s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Heterocide."⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Burn incense down to cashes"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Because most of them are pretty loose chang
# --------------------------------------------------------------------------------
# 💾 Batch 21 written to labelled_output.csv
# ✅ Batch 21 completed in 18.44s
#
# 🚀 Batch 22/20000 — Processing reviews 421 to 440
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 22.99s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "What? No, this is your friend Tô Hoài, let me in I have something important to tell you!"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"medium"⁓"true"⁓"false"
# "to whom?"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓
# --------------------------------------------------------------------------------
# 💾 Batch 22 written to labelled_output.csv
# ✅ Batch 22 completed in 22.99s
#
# 🚀 Batch 23/20000 — Processing reviews 441 to 460
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 26.88s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "I read "lingerie scent". I knew I was wrong the moment I came up to "toast". 🤦‍♂️ So, I doubt I will be of any help to you"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"medium"⁓"true"⁓"false"
# "You should switch to
# --------------------------------------------------------------------------------
# 💾 Batch 23 written to labelled_output.csv
# ✅ Batch 23 completed in 26.88s
#
# 🚀 Batch 24/20000 — Processing reviews 461 to 480
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 31.75s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "_><_"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"true"
# "that also, that on Reddit"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "I once Blueddit so hard, the algorithm asked for a
# --------------------------------------------------------------------------------
# 💾 Batch 24 written to labelled_output.csv
# ✅ Batch 24 completed in 31.75s
#
# 🚀 Batch 25/20000 — Processing reviews 481 to 500
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 15.86s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Your confession is safe with a prostitute."⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "One tempts with sin and one guides to remove it"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"medium"⁓"fa
# --------------------------------------------------------------------------------
# 💾 Batch 25 written to labelled_output.csv
# ✅ Batch 25 completed in 15.86s
# 😴 Sleeping for 5 seconds to prevent overload...
#
# 🚀 Batch 26/20000 — Processing reviews 501 to 520
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 25.94s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "That blows"⁓"negative"⁓"sincere"⁓"comment"⁓"true"⁓"low"⁓"false"⁓"false"
# "You can pick your friends. You can pick your nose. But you can't pick your friend's nose! ... Well... not with that attitude, anyway."
# --------------------------------------------------------------------------------
# 💾 Batch 26 written to labelled_output.csv
# ✅ Batch 26 completed in 25.94s
#
# 🚀 Batch 27/20000 — Processing reviews 521 to 540
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 20.11s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "His mummy didn’t approve"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Wow, that’s super dumb. Well done."⁓"negative"⁓"sarcastic"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "That was pharough
# --------------------------------------------------------------------------------
# 💾 Batch 27 written to labelled_output.csv
# ✅ Batch 27 completed in 20.11s
#
# 🚀 Batch 28/20000 — Processing reviews 541 to 560
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 23.0s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Good old #76 is a classic and you tell it well ;>)"⁓"positive"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Fetch!"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Clearly not Rover"⁓"neut
# --------------------------------------------------------------------------------
# 💾 Batch 28 written to labelled_output.csv
# ✅ Batch 28 completed in 23.0s
#
# 🚀 Batch 29/20000 — Processing reviews 561 to 580
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 23.28s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "What's brown and knocks on windows? A baby in a microwave!"⁓"negative"⁓"sarcastic"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "Loved it hahaha"⁓"positive"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "C
# --------------------------------------------------------------------------------
# 💾 Batch 29 written to labelled_output.csv
# ✅ Batch 29 completed in 23.28s
#
# 🚀 Batch 30/20000 — Processing reviews 581 to 600
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 27.49s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Heroin"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Shitty jokes"⁓"negative"⁓"sincere"⁓"comment"⁓"true"⁓"low"⁓"false"⁓"false"
# "I thought it was gonna be a racist joke"⁓"neutral"⁓"sincere"⁓"c
# --------------------------------------------------------------------------------
# 💾 Batch 30 written to labelled_output.csv
# ✅ Batch 30 completed in 27.49s
# 😴 Sleeping for 5 seconds to prevent overload...
#
# 🚀 Batch 31/20000 — Processing reviews 601 to 620
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 23.03s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "The whole country, because you’re a nation."⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"medium"⁓"true"⁓"false"
# "The State of being undressed"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "Tenn
# --------------------------------------------------------------------------------
# 💾 Batch 31 written to labelled_output.csv
# ✅ Batch 31 completed in 23.03s
#
# 🚀 Batch 32/20000 — Processing reviews 621 to 640
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 19.99s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Id call her whatever her name is.....I don't want ti get cursed."⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"true"⁓"false"
# "A hillbilly?"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Poor"⁓
# --------------------------------------------------------------------------------
# 💾 Batch 32 written to labelled_output.csv
# ✅ Batch 32 completed in 19.99s
#
# 🚀 Batch 33/20000 — Processing reviews 641 to 660
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 27.77s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Certainly NOT Bumbling Bee."⁓"negative"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Ion Man"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "If Dick is short for Richard, what’s Luke shor
# --------------------------------------------------------------------------------
# 💾 Batch 33 written to labelled_output.csv
# ✅ Batch 33 completed in 27.77s
#
# 🚀 Batch 34/20000 — Processing reviews 661 to 680
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 34.55s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "I could explain, but it involves some pushing and pulling that would probably get me banned here"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"true"⁓"false"
# "Kneeling behind a dumpster"⁓"neutral"⁓"sarcas
# --------------------------------------------------------------------------------
# 💾 Batch 34 written to labelled_output.csv
# ✅ Batch 34 completed in 34.55s
#
# 🚀 Batch 35/20000 — Processing reviews 681 to 700
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 23.31s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "You ask Richard nicely for it"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Just ask him."⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Well you could start with buying him a
# --------------------------------------------------------------------------------
# 💾 Batch 35 written to labelled_output.csv
# ✅ Batch 35 completed in 23.31s
# 😴 Sleeping for 5 seconds to prevent overload...
#
# 🚀 Batch 36/20000 — Processing reviews 701 to 720
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 22.51s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "But Syrup of Ipecac sounded very sexy when I saw it on the drugstore shelf."⁓"neutral"⁓"sarcastic"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "High fives all-around"⁓"positive"⁓"sincere"⁓"comment"⁓"false"⁓"l
# --------------------------------------------------------------------------------
# 💾 Batch 36 written to labelled_output.csv
# ✅ Batch 36 completed in 22.51s
#
# 🚀 Batch 37/20000 — Processing reviews 721 to 740
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 14.37s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "12 pieces of fruit. I ate one."⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Really big hands"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Two bags of fruit, perhaps?"⁓"neutr
# --------------------------------------------------------------------------------
# 💾 Batch 37 written to labelled_output.csv
# ✅ Batch 37 completed in 14.37s
#
# 🚀 Batch 38/20000 — Processing reviews 741 to 760
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 17.96s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Huge hands"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Fruit"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Too much fruit"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"medium"⁓"fa
# --------------------------------------------------------------------------------
# 💾 Batch 38 written to labelled_output.csv
# ✅ Batch 38 completed in 17.96s
#
# 🚀 Batch 39/20000 — Processing reviews 761 to 780
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 33.86s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "This joke sucks"⁓"negative"⁓"sincere"⁓"comment"⁓"true"⁓"low"⁓"false"⁓"false"
# "Delete This Post!"⁓"negative"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Finally... someone who understands proper date f
# --------------------------------------------------------------------------------
# 💾 Batch 39 written to labelled_output.csv
# ✅ Batch 39 completed in 33.86s
#
# 🚀 Batch 40/20000 — Processing reviews 781 to 800
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 18.01s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "A stick!"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Remove...1? A square with two sticks...💪"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "Please, guys, it's a play on t
# --------------------------------------------------------------------------------
# 💾 Batch 40 written to labelled_output.csv
# ✅ Batch 40 completed in 18.01s
# 😴 Sleeping for 5 seconds to prevent overload...
#
# 🚀 Batch 41/20000 — Processing reviews 801 to 820
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 27.4s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Some went to Massachusetts Integral Third finger. MIT."⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "Went to Screw U. Grades not good enuf for Fuck U."⁓"negative"⁓"sarcastic"⁓"comment"⁓"t
# --------------------------------------------------------------------------------
# 💾 Batch 41 written to labelled_output.csv
# ✅ Batch 41 completed in 27.4s
#
# 🚀 Batch 42/20000 — Processing reviews 821 to 840
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 37.35s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Try peeing while brushing your teeth 🪥"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "Cue sad trombone noises"⁓"negative"⁓"sarcastic"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "After the
# --------------------------------------------------------------------------------
# 💾 Batch 42 written to labelled_output.csv
# ✅ Batch 42 completed in 37.35s
#
# 🚀 Batch 43/20000 — Processing reviews 841 to 860
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 31.77s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Say thee neigh!!"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "Take them to a retirement community. Archeologists will date any old thing."⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"
# --------------------------------------------------------------------------------
# 💾 Batch 43 written to labelled_output.csv
# ✅ Batch 43 completed in 31.77s
#
# 🚀 Batch 44/20000 — Processing reviews 861 to 880
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 26.53s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Was her name Sally and did she sell seashells by thesea shore?"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "Silly. You don’t need the tattoo to whiff the beach 🏖️"⁓"neutral"⁓"sincere"⁓"co
# --------------------------------------------------------------------------------
# 💾 Batch 44 written to labelled_output.csv
# ✅ Batch 44 completed in 26.53s
#
# 🚀 Batch 45/20000 — Processing reviews 881 to 900
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 21.81s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Teeheehee. Sorry this made me laugh. I feel like this a dad joke xD"⁓"positive"⁓"sincere"⁓"comment"⁓"true"⁓"medium"⁓"true"⁓"false"
# "She's a chip off the old block lol"⁓"neutral"⁓"neutral"⁓"comment"⁓"true"⁓"m
# --------------------------------------------------------------------------------
# 💾 Batch 45 written to labelled_output.csv
# ✅ Batch 45 completed in 21.81s
# 😴 Sleeping for 5 seconds to prevent overload...
#
# 🚀 Batch 46/20000 — Processing reviews 901 to 920
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 29.16s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "...and doesn't at the same time."⁓"neutral"⁓"sarcastic"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "and if it doesn't suck, does that mean it sucks or that it doesn't suck?"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"
# --------------------------------------------------------------------------------
# 💾 Batch 46 written to labelled_output.csv
# ✅ Batch 46 completed in 29.16s
#
# 🚀 Batch 47/20000 — Processing reviews 921 to 940
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 24.72s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Call it by my ex’s name. Neither sucked."⁓"negative"⁓"sarcastic"⁓"review"⁓"true"⁓"medium"⁓"false"⁓"false"
# "I thought you was that bottom bitch. But I guess it’s ninja blender. Owww"⁓"negative"⁓"sarcastic"⁓"r
# --------------------------------------------------------------------------------
# 💾 Batch 47 written to labelled_output.csv
# ✅ Batch 47 completed in 24.72s
#
# 🚀 Batch 48/20000 — Processing reviews 941 to 960
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 34.02s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Bangers"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "Climbmydia?"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "I mean I guess they have to do something for all that t
# --------------------------------------------------------------------------------
# 💾 Batch 48 written to labelled_output.csv
# ✅ Batch 48 completed in 34.02s
#
# 🚀 Batch 49/20000 — Processing reviews 961 to 980
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 22.92s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Shouldn't the joke have read "need elp"? Then the answer is H"⁓neutral⁓neutral⁓comment⁓false⁓medium⁓true⁓false
# "elp"⁓neutral⁓neutral⁓comment⁓false⁓low⁓false⁓false
# "OMG. I didn't see that coming and nearly ch
# --------------------------------------------------------------------------------
# 💾 Batch 49 written to labelled_output.csv
# ✅ Batch 49 completed in 22.92s
#
# 🚀 Batch 50/20000 — Processing reviews 981 to 1000
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 28.62s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "To make 6 afraid of 7"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"true"⁓"false"
# "Because he was tired from 6."⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"true"⁓"false"
# "7, 8, 9"⁓"neutral"⁓"neutral"⁓"comm
# --------------------------------------------------------------------------------
# 💾 Batch 50 written to labelled_output.csv
# ✅ Batch 50 completed in 28.62s
# 😴 Sleeping for 5 seconds to prevent overload...
#
# 🚀 Batch 51/20000 — Processing reviews 1001 to 1020
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 29.11s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Make sure prior to showering to Chekov the list of hygiene products required and order appropriately."⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"true"⁓"false"
# "Talk about a Captains’ log.."⁓"negative"
# --------------------------------------------------------------------------------
# 💾 Batch 51 written to labelled_output.csv
# ✅ Batch 51 completed in 29.11s
#
# 🚀 Batch 52/20000 — Processing reviews 1021 to 1040
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 21.13s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Putin’s too highfalutin for that newton tootin’"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "This joke sucks harder than a starving vampire"⁓"negative"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓
# --------------------------------------------------------------------------------
# 💾 Batch 52 written to labelled_output.csv
# ✅ Batch 52 completed in 21.13s
#
# 🚀 Batch 53/20000 — Processing reviews 1041 to 1060
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 21.79s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Finally, an actual fucking joke"⁓"positive"⁓"sincere"⁓"comment"⁓"true"⁓"low"⁓"false"⁓"false"
# "The cop only heard him because of all the coffin."⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"true"⁓"false"
# --------------------------------------------------------------------------------
# 💾 Batch 53 written to labelled_output.csv
# ✅ Batch 53 completed in 21.79s
#
# 🚀 Batch 54/20000 — Processing reviews 1061 to 1080
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 34.87s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Playing Paki Man."⁓"negative"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "Luck 🤣"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"true"
# "2600?"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"
# --------------------------------------------------------------------------------
# 💾 Batch 54 written to labelled_output.csv
# ✅ Batch 54 completed in 34.87s
#
# 🚀 Batch 55/20000 — Processing reviews 1081 to 1100
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 19.83s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Slipping Through My Fingers"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "You’re the dancing queen, young and sweet, only seventeen"⁓"positive"⁓"sincere"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"f
# --------------------------------------------------------------------------------
# 💾 Batch 55 written to labelled_output.csv
# ✅ Batch 55 completed in 19.83s
# 😴 Sleeping for 5 seconds to prevent overload...
#
# 🚀 Batch 56/20000 — Processing reviews 1101 to 1120
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 19.88s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Chiquitita"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Any of them"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Mamma mia, here we go again"⁓"neutral"⁓"neutral"⁓"comment"⁓"
# --------------------------------------------------------------------------------
# 💾 Batch 56 written to labelled_output.csv
# ✅ Batch 56 completed in 19.88s
#
# 🚀 Batch 57/20000 — Processing reviews 1121 to 1140
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 32.88s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "now im happyy hihi"⁓"positive"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "🤦‍♀️"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"true"
# "Proctologist."⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"
# --------------------------------------------------------------------------------
# 💾 Batch 57 written to labelled_output.csv
# ✅ Batch 57 completed in 32.88s
#
# 🚀 Batch 58/20000 — Processing reviews 1141 to 1160
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 14.83s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "I’ve seen him in something… Journey to the Center of Oneself?"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "perfect timing"⁓"positive"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Bu
# --------------------------------------------------------------------------------
# 💾 Batch 58 written to labelled_output.csv
# ✅ Batch 58 completed in 14.83s
#
# 🚀 Batch 59/20000 — Processing reviews 1161 to 1180
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 31.34s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Names"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Neil!"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Thighler"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"fals
# --------------------------------------------------------------------------------
# 💾 Batch 59 written to labelled_output.csv
# ✅ Batch 59 completed in 31.34s
#
# 🚀 Batch 60/20000 — Processing reviews 1181 to 1200
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 28.43s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Kind of an inevitability of parthenogenesis"⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"medium"⁓"true"⁓"false"
# "She didn’t like getting nailed though."⁓"negative"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"true"⁓"fa
# --------------------------------------------------------------------------------
# 💾 Batch 60 written to labelled_output.csv
# ✅ Batch 60 completed in 28.43s
# 😴 Sleeping for 5 seconds to prevent overload...
#
# 🚀 Batch 61/20000 — Processing reviews 1201 to 1220
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 24.91s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Acts talks about how the apostles were all in one Accord."⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "A prayus?"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "A Honda
# --------------------------------------------------------------------------------
# 💾 Batch 61 written to labelled_output.csv
# ✅ Batch 61 completed in 24.91s
#
# 🚀 Batch 62/20000 — Processing reviews 1221 to 1240
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 46.03s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "had a crysler concord that was haunted by intermittent breakdowns, issues. it will forever be known as the AntiCrysler"⁓"negative"⁓"sincere"⁓"comment"⁓"false"⁓"medium"⁓"true"⁓"false"
# "A CrossTrek"⁓"neutral"⁓
# --------------------------------------------------------------------------------
# 💾 Batch 62 written to labelled_output.csv
# ✅ Batch 62 completed in 46.03s
#
# 🚀 Batch 63/20000 — Processing reviews 1241 to 1260
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 15.1s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Yo Ho"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "A nun can’t numb but a prostitute can"⁓"negative"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "now yyou should know whyyy"⁓"neutr
# --------------------------------------------------------------------------------
# 💾 Batch 63 written to labelled_output.csv
# ✅ Batch 63 completed in 15.1s
#
# 🚀 Batch 64/20000 — Processing reviews 1261 to 1280
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 20.96s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Ikr"⁓"neutral"⁓"neutral"⁓"comment"⁓"true"⁓"low"⁓"false"⁓"false"
# "Iykyk"⁓"neutral"⁓"neutral"⁓"comment"⁓"true"⁓"low"⁓"false"⁓"false"
# "Why are celibate drivers the worst? They don't give a fuck."⁓"negative"⁓"si
# --------------------------------------------------------------------------------
# 💾 Batch 64 written to labelled_output.csv
# ✅ Batch 64 completed in 20.96s
#
# 🚀 Batch 65/20000 — Processing reviews 1281 to 1300
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 24.04s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Has he had it in the ear before???"⁓"negative"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Some free time"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Wrong, if he goes half way he's
# --------------------------------------------------------------------------------
# 💾 Batch 65 written to labelled_output.csv
# ✅ Batch 65 completed in 24.04s
# 😴 Sleeping for 5 seconds to prevent overload...
#
# 🚀 Batch 66/20000 — Processing reviews 1301 to 1320
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 32.0s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Do you realise what this means?"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "For those who are confused: Billy factually reported that he cannot tell the class the meaning of the word. The t
# --------------------------------------------------------------------------------
# 💾 Batch 66 written to labelled_output.csv
# ✅ Batch 66 completed in 32.0s
#
# 🚀 Batch 67/20000 — Processing reviews 1321 to 1340
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 28.31s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Just make sure it doesn’t *defrost* halfway through the bridge"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "Dance w the fridge😎"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"fal
# --------------------------------------------------------------------------------
# 💾 Batch 67 written to labelled_output.csv
# ✅ Batch 67 completed in 28.31s
#
# 🚀 Batch 68/20000 — Processing reviews 1341 to 1360
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 15.23s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Kneel"⁓"neutral"⁓"neutral"⁓"review"⁓"false"⁓"low"⁓"false"⁓"false"
# "Please join us in the Benadiction."⁓"neutral"⁓"sarcastic"⁓"review"⁓"true"⁓"medium"⁓"false"⁓"false"
# "Kneel and pray. Thou shall receive"⁓"neu
# --------------------------------------------------------------------------------
# 💾 Batch 68 written to labelled_output.csv
# ✅ Batch 68 completed in 15.23s
#
# 🚀 Batch 69/20000 — Processing reviews 1361 to 1380
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 31.5s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "You best be believin’"⁓"neutral"⁓"sincere"⁓"review"⁓"false"⁓"low"⁓"false"⁓"false"
# "Kneel."⁓"neutral"⁓"neutral"⁓"review"⁓"false"⁓"low"⁓"false"⁓"false"
# "Down on your knees"⁓"neutral"⁓"sarcastic"⁓"review"⁓"true
# --------------------------------------------------------------------------------
# 💾 Batch 69 written to labelled_output.csv
# ✅ Batch 69 completed in 31.5s
#
# 🚀 Batch 70/20000 — Processing reviews 1381 to 1400
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 36.76s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Snort Boarding"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "Probably not football"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Ham gliding"⁓"neutral"⁓"sarcastic"⁓"commen
# --------------------------------------------------------------------------------
# 💾 Batch 70 written to labelled_output.csv
# ✅ Batch 70 completed in 36.76s
# 😴 Sleeping for 5 seconds to prevent overload...
#
# 🚀 Batch 71/20000 — Processing reviews 1401 to 1420
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 27.01s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "She didn’t do it. I’m Uncle Gravity. Lies. All lies."⁓"negative"⁓"sincere"⁓"comment"⁓"false"⁓"medium"⁓"true"⁓"false"
# "It’s only light reading."⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "Fu
# --------------------------------------------------------------------------------
# 💾 Batch 71 written to labelled_output.csv
# ✅ Batch 71 completed in 27.01s
#
# 🚀 Batch 72/20000 — Processing reviews 1421 to 1440
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 24.67s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "The sun actually rises?"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "You can see the sun?"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"false"⁓"medium"⁓"false"⁓"false"
# "One is extremely hot and shi
# --------------------------------------------------------------------------------
# 💾 Batch 72 written to labelled_output.csv
# ✅ Batch 72 completed in 24.67s
#
# 🚀 Batch 73/20000 — Processing reviews 1441 to 1460
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 26.42s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "Lemons Le_ons. M L__ons. Me ___ons. Mel ____ns. Melo _____s. Melon ______. Melons"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"true"
# "Hang in there… unless you’re laundry. Want to start a midnight
# --------------------------------------------------------------------------------
# 💾 Batch 73 written to labelled_output.csv
# ✅ Batch 73 completed in 26.42s
#
# 🚀 Batch 74/20000 — Processing reviews 1461 to 1480
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 28.7s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "You can probably see the sun too."⁓"neutral"⁓"sincere"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"false"
# "I’ve never been reported to HR for sending a sun pick"⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓
# --------------------------------------------------------------------------------
# 💾 Batch 74 written to labelled_output.csv
# ✅ Batch 74 completed in 28.7s
#
# 🚀 Batch 75/20000 — Processing reviews 1481 to 1500
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 22.78s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "One goes down at night-the other goes up (hopefully)."⁓"neutral"⁓"sarcastic"⁓"comment"⁓"true"⁓"medium"⁓"false"⁓"false"
# "The sun is not flaccid. Ah damn it, I knew I was close"⁓"negative"⁓"sarcastic"⁓"comment
# --------------------------------------------------------------------------------
# 💾 Batch 75 written to labelled_output.csv
# ✅ Batch 75 completed in 22.78s
# 😴 Sleeping for 5 seconds to prevent overload...
#
# 🚀 Batch 76/20000 — Processing reviews 1501 to 1520
# 🧪 Trying model: gemini-2.5-flash
# ✅ Model gemini-2.5-flash succeeded.
# ⏱️ Output generated in 25.0s
# 🔍 Output Preview:
#  "text"⁓"label"⁓"tone"⁓"context"⁓"contains_slang"⁓"complexity"⁓"causal"⁓"contains_gibberish"
# "One rises, the other does not."⁓negative⁓sarcastic⁓comment⁓true⁓medium⁓false⁓false
# ""Erectile Dysfunction is not a joke, Jim!""⁓negative⁓sarcastic⁓comment⁓true⁓medium⁓false⁓false
# ...
# 🧪 Trying model: gemini-2.5-pro
# ✅ Model gemini-2.5-pro succeeded.
# ⏱️ Output generated in 68.89s
# 🔍 Output Preview:
#  "text","label","tone","context","contains_slang","complexity","causal","contains_gibberish"
# "![gif](giphy|m7FdxI252QN3y)"⁓"neutral"⁓"neutral"⁓"comment"⁓"false"⁓"low"⁓"false"⁓"true"
# "My boy out here killing younglings I guess."⁓"neutral"⁓"sincere"⁓"comment"⁓"true"⁓"low"⁓"false"⁓"false"
# "Lmao literal
# --------------------------------------------------------------------------------
# 💾 Batch 264 written to labelled_output.csv
# ✅ Batch 264 completed in 68.89s
#
# 🚀 Batch 265/20000 — Processing reviews 5281 to 5300
# 🧪 Trying model: gemini-2.5-flash
# ❌ Error using model gemini-2.5-flash: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '250'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '33s'}]}}
# 🧪 Trying model: gemini-2.5-pro
# ❌ Error using model gemini-2.5-pro: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# 🚫 Skipping batch 265 due to total model failure.
#
# 🚀 Batch 266/20000 — Processing reviews 5301 to 5320
# 🧪 Trying model: gemini-2.5-flash
# ❌ Error using model gemini-2.5-flash: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '250'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '30s'}]}}
# 🧪 Trying model: gemini-2.5-pro
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 70
#      68 try:
#      69     print(f"🧪 Trying model: {model_name}")
# ---> 70     response = client.models.generate_content(
#      71         model=model_name,
#      72         contents=prompt
#      73     )
#      75     if hasattr(response, 'text') and response.text:
#      76         raw_output = response.text.strip()
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/google/genai/models.py:5898, in Models.generate_content(self, model, contents, config)
#    5896 while remaining_remote_calls_afc > 0:
#    5897   i += 1
# -> 5898   response = self._generate_content(
#    5899       model=model, contents=contents, config=parsed_config
#    5900   )
#    5901   logger.info(f'AFC remote call {i} is done.')
#    5902   remaining_remote_calls_afc -= 1
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/google/genai/models.py:4838, in Models._generate_content(self, model, contents, config)
#    4835 request_dict = _common.convert_to_dict(request_dict)
#    4836 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4838 response = self._api_client.request(
#    4839     'post', path, request_dict, http_options
#    4840 )
#    4842 response_dict = '' if not response.body else json.loads(response.body)
#    4844 if self._api_client.vertexai:
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/google/genai/_api_client.py:1077, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1067 def request(
#    1068     self,
#    1069     http_method: str,
#    (...)
#    1072     http_options: Optional[HttpOptionsOrDict] = None,
#    1073 ) -> SdkHttpResponse:
#    1074   http_request = self._build_request(
#    1075       http_method, path, request_dict, http_options
#    1076   )
# -> 1077   response = self._request(http_request, stream=False)
#    1078   response_body = (
#    1079       response.response_stream[0] if response.response_stream else ''
#    1080   )
#    1081   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/google/genai/_api_client.py:968, in BaseApiClient._request(self, http_request, stream)
#     963 def _request(
#     964     self,
#     965     http_request: HttpRequest,
#     966     stream: bool = False,
#     967 ) -> HttpResponse:
# --> 968   return self._retry(self._request_once, http_request, stream)
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/tenacity/__init__.py:398, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     396 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398         self._add_action_func(lambda rs: rs.outcome.result())
#     399         return
#     401     if self.after is not None:
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/google/genai/_api_client.py:951, in BaseApiClient._request_once(self, http_request, stream)
#     947   return HttpResponse(
#     948       response.headers, response if stream else [response.text]
#     949   )
#     950 else:
# --> 951   response = self._httpx_client.request(
#     952       method=http_request.method,
#     953       url=http_request.url,
#     954       headers=http_request.headers,
#     955       content=data,
#     956       timeout=http_request.timeout,
#     957   )
#     958   errors.APIError.raise_for_response(response)
#     959   return HttpResponse(
#     960       response.headers, response if stream else [response.text]
#     961   )
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)
#     823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
